# %%
# !pip install -i https://test.pypi.org/simple/ ising-model
# !pip install matplotlib
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: ising-model in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (0.0.7)
# Requirement already satisfied: numpy in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from ising-model) (2.4.4)
# Requirement already satisfied: numba in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from ising-model) (0.65.1)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from numba->ising-model) (0.47.0)
# Requirement already satisfied: matplotlib in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/graca/Desktop/rse-python-course/rse-ising-model/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt
from ising_model.ising_model import init_random_grid, run_ising_model

# %%
rows, cols = 300, 300
grid = init_random_grid(rows, cols)
T = 1
steps = 100_000_000

plt.imshow(grid)
plt.show()

# %%
res = run_ising_model(grid, T, steps)

plt.imshow(res)
plt.show()
